# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import imageio

# %%
from scripts.cargar import DataLoader
from scripts.clasificador import Clasificador
from scripts.detector import FruitDetector
from scripts.detector_utils import *
from scripts.video import RealTimeDetector

# %%
#Instancia del dataloader
datasets = DataLoader()
#datasets = DataLoader(DATA_DIR='test_dataset/') #Para usar datos de test
bananas_ds,ciruelas_ds,kiwis_ds,mangos_ds,manzanas_ds,naranjas_ds = datasets.todos()

# %%
#Instancia del clasificador
clasificador = Clasificador()

# %%
#Instancia del detector para analizar el dataset
detector = FruitDetector(analysis=True,split=False).get()

# %% [markdown]
# ## Métricas para cada fruta

# %%
detector.analizar_todas(datasets)
# Out:
# tercer momento 1.71
# mape 4.43%
# porcentaje de acierto 85.00%

# %%
detector.detectar_mango(mangos_ds)
# Out:
# tercer momento 1.69
# mape 1.90%
# porcentaje de acierto 92.06%

# %%
detector.detectar_kiwi(kiwis_ds)
# Out:
# tercer momento 6.35
# mape 1.22%
# porcentaje de acierto 96.83%

# %%
detector.detectar_manzana(manzanas_ds)
# Out:
# tercer momento 1.22
# mape 12.42%
# porcentaje de acierto 79.37%

# %%
detector.detectar_ciruela(ciruelas_ds)
# Out:
# tercer momento 1.44
# mape 3.12%
# porcentaje de acierto 82.54%

# %%
detector.detectar_naranja(naranjas_ds)
# Out:
# tercer momento 7.75
# mape 1.59%
# porcentaje de acierto 98.41%

# %%
detector.detectar_banana(bananas_ds)
# Out:
# tercer momento 1.67
# mape 15.50%
# porcentaje de acierto 73.02%

# %% [markdown]
# ## Métricas globales

# %%
detector = FruitDetector(analysis=True,split=False).get()

# %%
datasets = DataLoader() #Dataset de base para train
detector.analizar_todas(datasets)
# Out:
# tercer momento 2.02
# mape 5.96%
# porcentaje de acierto 87.04%

# %%
datasets = DataLoader(DATA_DIR='test_dataset/') #Dataset de imagenes de test
detector.analizar_todas(datasets)
# Out:
# tercer momento 1.71
# mape 4.43%
# porcentaje de acierto 85.00%

# %% [markdown]
# ## Clasificación y detección de una imagen

# %%
detector = FruitDetector(analysis=False,split=True).get()

# %%
img = bananas_ds[0][0]

detectadas,img_aux,pred = detector.contar_detectar(img,clasificador)

print("Clase:{} Detectadas:{}".format(pred,detectadas))
show(img_aux[...,::-1])
# Out:
# Clase:Banana Detectadas:5

# %%
#Detector en tiempo real desde camara de PC
rtd = RealTimeDetector()
rtd.detectar(clasificador,detector)
